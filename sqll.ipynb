# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import mysql.connector as sql

mydb = sql.connect(
    host = "localhost",
    user = "root",
    password = "MysqlRoot@133",
    )
print(mydb)

# %%
mycursor = mydb.cursor()

# %%
# mycursor.execute("CREATE DATABASE Transaction_data", if_exists='replace')

# %%
mycursor.execute("SHOW DATABASES")

# %%
for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('transaction_data',)

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlalchemy as db
from sqlalchemy import text
from sqlalchemy import *

# %%
engine = create_engine('mysql+mysqlconnector://root:MysqlRoot%40133@localhost/transaction_data', pool_size = -1, max_overflow = -1)
conn = engine.connect()

# %%
query = text(""" SELECT Revenue_max_Sep 
                        FROM country_table 
                        WHERE  country_table.Country = "Australia" """)

# %%
output  = conn.execute(query)
results = {'answer':output.scalars().all()[0]}

# %%
results
# Out:
# {'answer': 1658.88}

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import sqlalchemy as db
db.__version__
from sqlalchemy import create_engine
# import pyodbc

# %%
# Create a sample DataFrame
df1 = pd.read_csv('Country_dataframe.csv')
df2 = pd.read_csv('Customer_dataframe.csv')

# %%
# Create a connection to a MySQL database
engine = db.create_engine('mysql+mysqlconnector://root:MysqlRoot%40133@localhost/transaction_data', pool_size = -1, max_overflow = -1)
conn = engine.connect()
metadat = db.MetaData

# %%
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost/transaction_data)

# %%
# Write the DataFrame to a SQL table
df1.to_sql('country_table', engine, if_exists='replace', index=False)
# Out:
# 38

# %%
country_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 country_table
#
# NameError: name 'country_table' is not defined

# %%
# Verify by reading from the table
result1 = pd.read_sql('SELECT * FROM country_table', con=engine)
print(result1)
# Out:
#                  Country  Revenue computation of max in year 2018  \
# 0              Australia                                  5221.44
# 1                Austria                                  1490.40
# 2                Bahrain                                   852.12
# 3                Belgium                                   683.10
# 4                 Brazil                                   725.76
# 5                 Canada                                  2280.90
# 6        Channel Islands                                  1690.56
# 7                 Cyprus                                  1327.68
# 8         Czech Republic                                   293.76
# 9                Denmark                                  1775.52
# 10                  EIRE                                  9797.76
# 11    European Community                                   248.40
# 12               Finland                                  2281.98
# ...

# %%
dir(engine.engine)
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_compiled_cache',
#  '_connection_cls',
#  '_echo',
#  '_execution_options',
#  '_has_events',
#  '_is_future',
#  '_lru_size_alert',
#  '_option_cls',
#  '_optional_conn_ctx_manager',
#  '_run_ddl_visitor',
#  '_schema_translate_map',
#  '_should_log_debug',
#  '_should_log_info',
#  '_sqla_logger_namespace',
#  'begin',
#  'clear_compiled_cache',
#  'connect',
#  'dialect',
#  'dispatch',
#  'dispose',
#  'driver',
#  'echo',
#  'engine',
# ...

# %%
print(engine.table_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(engine.table_names)
#
# AttributeError: 'Engine' object has no attribute 'table_names'

# %%
output = conn.execute("SELECT * FROM country_table")
print(output.fetchall())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\khyal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1414, in Connection.execute(self, statement, parameters, execution_options)
#    1413 try:
# -> 1414     meth = statement._execute_on_connection
#    1415 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 output = conn.execute("SELECT * FROM country_table")
#       2 print(output.fetchall())
#
# File c:\Users\khyal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
# ...

# %%
result3 = pd.read_sql('SELECT * FROM country_table WHERE Country == Austria', con=engine)
print(result3)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\khyal\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:697, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     696         query = query.encode("utf-8")
# --> 697     self._cmysql.query(
#     698         query,
#     699         raw=raw,
#     700         buffered=buffered,
#     701         raw_as_string=raw_as_string,
#     702         query_attrs=self.query_attrs,
#     703     )
#     704 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '== Austria' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2.to_sql('customer_table', engine, if_exists='replace', index=False)
# Out:
# 4373

# %%
result2 = pd.read_sql('SELECT * FROM customer_table', con=engine)
print(result2)
# Out:
#       UserId  Expenditure max in year 2018  Expenditure max in year 2019  \
# 0         -1                      45796.95                      19814.40
# 1     259266                     320608.80                          0.00
# 2     259287                       1036.80                        440.64
# 3     259308                        993.60                          0.00
# 4     259329                          0.00                       1242.00
# ...      ...                           ...                           ...
# 4368  383880                         98.19                          0.00
# 4369  383901                         70.20                          0.00
# 4370  383922                         95.04                        105.60
# 4371  383943                         73.44                         86.40
# 4372  384027                        361.80                        186.84
#
#       Expenditure max in year 2028  Expenditure mean in year 2018  \
# ...

# %%
pip install fastapi
# Out:
# ...
#      ---------------------------------------- 0.0/123.5 kB ? eta -:--:--
#      -------------------------------------  122.9/123.5 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 123.5/123.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 51.6/51.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 92.0/92.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB 7.7 MB/s eta 0:00:00
# ...
